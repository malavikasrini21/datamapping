# %%
import pandas as pd
import sklearn
n='TargetDataBasecsv.csv'
df=pd.read_csv(n)

# %%
ym=df.columns.values.tolist()

# %%
da=df['Acct_FName']
from pandas import DataFrame
le=[]
for j in ym:
    for i in range(len(da)):
        le.append(j)
    dx = DataFrame(le,columns=['Target'])

# %%
import pandas as pd
import sklearn
df=pd.read_csv('TargetDataBasecsv.csv')
da=df['Acct_FName']
le=[]
for k in ym:
    
    for l in df[k]:
        le.append(l)
    ds= DataFrame(le,columns=['X'])

# %%
df_index = pd.merge(ds, dx, right_index=True, left_index=True)

# %%
import pandas as pd
jk=[]
for i in df_index["X"]:
    try:
        jk.append(len(i))
        #kl=pd.DataFrame(jk,columns=['leng'])
        
    except:
        jk.append(0)
        #kl=pd.DataFrame(jk,columns=['leng'])
import numpy as np
kl = pd.DataFrame(np.array([jk]).T)
kl.columns =['leng']

# %%
df_index = pd.merge(ds, kl, right_index=True, left_index=True)

# %%
import pandas as pd
jk=[]
for i in df_index["X"]:
    try:
        c=0
        for j in i:
            if j==' ':
                c=c+1
        jk.append(c)
        
        
    except:
        jk.append(0)

import numpy as np
ty = pd.DataFrame(np.array([jk]).T)
ty.columns =['Spaces']

# %%
df_fin = pd.merge(df_index, ty, right_index=True, left_index=True)

# %%
df_final = pd.merge(df_fin,dx, right_index=True, left_index=True)

# %%
import pandas as pd
jk=[]
for i in df_index["X"]:
    try:
        c=0
        for j in i:
            if j==' ' or j.isalnum()==False:
                c=c+1
        jk.append(c)
        
        
    except:
        jk.append(0)

import numpy as np
ty = pd.DataFrame(np.array([jk]).T)
ty.columns =['Spaces']

# %%
import pandas as pd
jk=[]
for i in df_index["X"]:
    try:
        c=0
        for j in i:
            if j.isalnum==False:
                c=c+1
        jk.append(c)
        
        
    except:
        jk.append(0)

import numpy as np
tz = pd.DataFrame(np.array([jk]).T)
tz.columns =['special char']



latest= pd.merge(df_fin,tz, right_index=True, left_index=True)

latest
# Out:
#                X  leng  Spaces  special char
# 0      C00000001     9       0             0
# 1      C00000002     9       0             0
# 2      C00000003     9       0             0
# 3      C00000004     9       0             0
# 4      C00000005     9       0             0
# ...          ...   ...     ...           ...
# 69792     Female     6       0             0
# 69793       Male     4       0             0
# 69794       Male     4       0             0
# 69795     Female     6       0             0
# 69796     Female     6       0             0
#
# [69797 rows x 4 columns]

# %%
import pandas as pd

fs=[]
a=[]
for i in df_index["X"]:
    try:
        c=0
    
        for j in i:
            
            
            if j.isdigit() or j=='-':
                a.append(j)
                c=1
        fs.append(c)
        
        
    except:
        fs.append(0)
#print(a)

newfs = pd.DataFrame(np.array([fs]).T)
newfs.columns =['Only digits']
#print(newfs)
feature=pd.merge(latest,newfs, right_index=True, left_index=True)
feature
# Out:
#                X  leng  Spaces  special char  Only digits
# 0      C00000001     9       0             0            1
# 1      C00000002     9       0             0            1
# 2      C00000003     9       0             0            1
# 3      C00000004     9       0             0            1
# 4      C00000005     9       0             0            1
# ...          ...   ...     ...           ...          ...
# 69792     Female     6       0             0            0
# 69793       Male     4       0             0            0
# 69794       Male     4       0             0            0
# 69795     Female     6       0             0            0
# 69796     Female     6       0             0            0
#
# [69797 rows x 5 columns]

# %%
import pandas as pd

qq=[]
b=[]
for i in df_index["X"]:
    try:
        c=0
    
        
            
        
        if i=='Female' or i=='Male' or i=='F' or i=='M':
                b.append(i)
                c=99
        qq.append(c)
        
        
    except:
        qq.append(90)
#print(a)

gen = pd.DataFrame(np.array([qq]).T)
gen.columns =['Gender']
#print(newfs)
fea=pd.merge(latest,gen, right_index=True, left_index=True)
fea
# Out:
#                X  leng  Spaces  special char  Gender
# 0      C00000001     9       0             0       0
# 1      C00000002     9       0             0       0
# 2      C00000003     9       0             0       0
# 3      C00000004     9       0             0       0
# 4      C00000005     9       0             0       0
# ...          ...   ...     ...           ...     ...
# 69792     Female     6       0             0      99
# 69793       Male     4       0             0      99
# 69794       Male     4       0             0      99
# 69795     Female     6       0             0      99
# 69796     Female     6       0             0      99
#
# [69797 rows x 5 columns]

# %%
df_final = pd.merge(fea,dx, right_index=True, left_index=True)

df_final
# Out:
#                X  leng  Spaces  special char  Gender       Target
# 0      C00000001     9       0             0       0      Acct_id
# 1      C00000002     9       0             0       0      Acct_id
# 2      C00000003     9       0             0       0      Acct_id
# 3      C00000004     9       0             0       0      Acct_id
# 4      C00000005     9       0             0       0      Acct_id
# ...          ...   ...     ...           ...     ...          ...
# 69792     Female     6       0             0      99  Acct_Gender
# 69793       Male     4       0             0      99  Acct_Gender
# 69794       Male     4       0             0      99  Acct_Gender
# 69795     Female     6       0             0      99  Acct_Gender
# 69796     Female     6       0             0      99  Acct_Gender
#
# [69797 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()

# %%
df_final['Target']=Le.fit_transform(df_final['Target'])
df_final
# Out:
#                X  leng  Spaces  special char  Gender  Target
# 0      C00000001     9       0             0       0      11
# 1      C00000002     9       0             0       0      11
# 2      C00000003     9       0             0       0      11
# 3      C00000004     9       0             0       0      11
# 4      C00000005     9       0             0       0      11
# ...          ...   ...     ...           ...     ...     ...
# 69792     Female     6       0             0      99       5
# 69793       Male     4       0             0      99       5
# 69794       Male     4       0             0      99       5
# 69795     Female     6       0             0      99       5
# 69796     Female     6       0             0      99       5
#
# [69797 rows x 6 columns]

# %%
ds_final=df_final.drop(columns='X')
ds_final
# Out:
#        leng  Spaces  special char  Gender  Target
# 0         9       0             0       0      11
# 1         9       0             0       0      11
# 2         9       0             0       0      11
# 3         9       0             0       0      11
# 4         9       0             0       0      11
# ...     ...     ...           ...     ...     ...
# 69792     6       0             0      99       5
# 69793     4       0             0      99       5
# 69794     4       0             0      99       5
# 69795     6       0             0      99       5
# 69796     6       0             0      99       5
#
# [69797 rows x 5 columns]

# %%
da=df['Acct_FName']
from pandas import DataFrame
le=[]
for j in ym:
    for i in range(len(da)):
        le.append(j)
    dq_final = DataFrame(le,columns=['Targetname'])

# %%
le=[]
for i in df_final['Target']:
    le.append(i)
da_final = DataFrame(le,columns=['Target'])

# %%
refftab = pd.merge(dq_final,da_final, right_index=True, left_index=True)
namel=refftab.Targetname.unique()
tarl=refftab.Target.unique()
namel=pd.DataFrame(namel,columns=['Targetname'])
tarl=pd.DataFrame(tarl,columns=['Targets'])
refftab = pd.merge(namel,tarl, right_index=True, left_index=True)
refftab
# Out:
#      Targetname  Targets
# 0       Acct_id       11
# 1   Acct_UIDNo.        9
# 2    Acct_FName        4
# 3    Acct_MName        7
# 4    Acct_LName        6
# 5    Acct_Addr1        0
# 6    Acct_Addr2        1
# 7     Acct_City        2
# 8    Acct_State        8
# 9    Acct_phone       12
# 10   Acct_email       10
# 11     Acct_DOB        3
# 12  Acct_Gender        5

# %%
ds_final
# Out:
#        leng  Spaces  special char  Gender  Target
# 0         9       0             0       0      11
# 1         9       0             0       0      11
# 2         9       0             0       0      11
# 3         9       0             0       0      11
# 4         9       0             0       0      11
# ...     ...     ...           ...     ...     ...
# 69792     6       0             0      99       5
# 69793     4       0             0      99       5
# 69794     4       0             0      99       5
# 69795     6       0             0      99       5
# 69796     6       0             0      99       5
#
# [69797 rows x 5 columns]

# %%
import sklearn 
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.10)
y_expect=y_test

# %%
MultiNB=MultinomialNB()
MultiNB.fit(X_train,y_train)
print(MultiNB)
y_pred=MultiNB.predict(X_test)
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# MultinomialNB()
# 0.09287719194822672

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
import sklearn 
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.10, random_state=20)
y_expect=y_test

# %%
GausNB=GaussianNB()
GausNB.fit(X_train,y_train)
print(GausNB)
y_pred=GausNB.predict(X_test)
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# GaussianNB()
# 0.6743589712682491

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
import sklearn 
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.10)
y_expect=y_test
BerNB=BernoulliNB()
BerNB.fit(X_train,y_train)
print(BerNB)
y_pred=BerNB.predict(X_test)
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# BernoulliNB()
# 0.11263245219027122

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
import sklearn 
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.20)
y_expect=y_test

# %%
clf=svm.SVC(kernel='rbf',C=30,gamma='auto')
clf.fit(X_train,y_train)
print(clf)
y_pred=clf.predict(X_test)
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# SVC(C=30, gamma='auto')
# 0.7789478494647448

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
import sklearn 
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.20)
y_expect=y_test

# %%
clf=SVC()

clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %%
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# 0.73765139665207

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
import sklearn 
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=15)
y_expect=y_test

# %%
dectr = tree.DecisionTreeClassifier()
dectr= dectr.fit(X_train, y_train)
y_pred=dectr.predict(X_test)
f1_score(y_expect, y_pred, average='macro')
# Out:
# 0.8014341404609486

# %%
s=f1_score(y_expect, y_pred, average='macro')
l=len(ds_final)
lj=[]
for i in range(l):
    lj.append(s)
lj=DataFrame(lj,columns=['F1Score'])
lj
# Out:
#         F1Score
# 0      0.801434
# 1      0.801434
# 2      0.801434
# 3      0.801434
# 4      0.801434
# ...         ...
# 69792  0.801434
# 69793  0.801434
# 69794  0.801434
# 69795  0.801434
# 69796  0.801434
#
# [69797 rows x 1 columns]

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
kk=[]
expectin=y_expect.index
for i in y_pred:
    
    kk.append(refftab.loc[refftab['Targets'] == i, 'Targetname'].iloc[0])
predicted=pd.DataFrame(kk,columns=['Predicted'])
kk=[]
for i in expectin:
    kk.append(dq_final._get_value(i,'Targetname'))
expected=pd.DataFrame(kk,columns=['expected'])
show = pd.merge(predicted,expected, right_index=True, left_index=True)
show
show1=pd.merge(show,lj,right_index=True, left_index=True)
show1
# Out:
#           expected    Predicted   F1Score
# 0          Acct_id      Acct_id  0.801434
# 1          Acct_id      Acct_id  0.801434
# 2       Acct_MName   Acct_MName  0.801434
# 3      Acct_UIDNo.  Acct_UIDNo.  0.801434
# 4       Acct_FName   Acct_FName  0.801434
# ...            ...          ...       ...
# 13955   Acct_FName   Acct_FName  0.801434
# 13956    Acct_City    Acct_City  0.801434
# 13957     Acct_DOB     Acct_DOB  0.801434
# 13958    Acct_City   Acct_phone  0.801434
# 13959   Acct_LName   Acct_LName  0.801434
#
# [13960 rows x 3 columns]

# %%
import sklearn 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
x=ds_final.drop(columns='Target')
y=ds_final['Target']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20)
y_expect=y_test
clf = RandomForestClassifier()
clf = clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(f1_score(y_expect, y_pred, average='macro'))
# Out:
# 0.755982246946262

# %%
import matplotlib.pyplot as plt  
plt.plot(y_pred,y_expect,'.')

# %%
output.to_csv('Sende.csv')

# %%
import pickle
filename='Decision_tree_model'
pickle.dump(dectr,open(filename,'wb'))

# %%
kk=[]
expectin=y_expect.index

for i in y_pred:
    
    kk.append(i)
predicted=pd.DataFrame(kk,columns=['Predicted'])
kk=[]
for i in expectin:
    kk.append(ds_final._get_value(i, 'Target'))
expected=pd.DataFrame(kk,columns=['expected'])
show = pd.merge(expected,predicted, right_index=True, left_index=True)
show
show2=pd.merge(show,lj,right_index=True, left_index=True)
header_list=['expected','Predicted','F1Score','Accept','Change']
show2 = show2.reindex(columns = header_list)
show2
# Out:
#        expected  Predicted   F1Score  Accept  Change
# 0            11         11  0.801434     NaN     NaN
# 1            11         11  0.801434     NaN     NaN
# 2             7          7  0.801434     NaN     NaN
# 3             9          9  0.801434     NaN     NaN
# 4             4          4  0.801434     NaN     NaN
# ...         ...        ...       ...     ...     ...
# 13955         4          4  0.801434     NaN     NaN
# 13956         2          2  0.801434     NaN     NaN
# 13957         3          3  0.801434     NaN     NaN
# 13958         2         12  0.801434     NaN     NaN
# 13959         6          6  0.801434     NaN     NaN
#
# [13960 rows x 5 columns]

# %%
print(show2.expected[0])
# Out:
# 11

# %%
for i in range(len(show2)):
    show2.F1Score[i]=((abs(10.0-abs(show2.expected[i]-show2.Predicted[i])))*10.0)/100
    

show2=show2.drop(columns=['expected','Predicted'])
show2
# Out:
# <ipython-input-31-ffe96f811f82>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   show2.F1Score[i]=((abs(10.0-abs(show2.expected[i]-show2.Predicted[i])))*10.0)/100
#        F1Score  Accept  Change
# 0          1.0     NaN     NaN
# 1          1.0     NaN     NaN
# 2          1.0     NaN     NaN
# 3          1.0     NaN     NaN
# 4          1.0     NaN     NaN
# ...        ...     ...     ...
# 13955      1.0     NaN     NaN
# 13956      1.0     NaN     NaN
# 13957      1.0     NaN     NaN
# 13958      0.0     NaN     NaN
# 13959      1.0     NaN     NaN
#
# [13960 rows x 3 columns]

# %%
result=(show2.F1Score.sum(axis=0))/len(show2.F1Score)
result
# Out:
# 0.935093123209169

# %%
show1=show1.drop(columns='F1Score')
show1
# Out:
#           expected    Predicted
# 0          Acct_id      Acct_id
# 1          Acct_id      Acct_id
# 2       Acct_MName   Acct_MName
# 3      Acct_UIDNo.  Acct_UIDNo.
# 4       Acct_FName   Acct_FName
# ...            ...          ...
# 13955   Acct_FName   Acct_FName
# 13956    Acct_City    Acct_City
# 13957     Acct_DOB     Acct_DOB
# 13958    Acct_City   Acct_phone
# 13959   Acct_LName   Acct_LName
#
# [13960 rows x 2 columns]

# %%
output = pd.merge(show1,show2, right_index=True, left_index=True)
output
# Out:
#           expected    Predicted  F1Score  Accept  Change
# 0          Acct_id      Acct_id      1.0     NaN     NaN
# 1          Acct_id      Acct_id      1.0     NaN     NaN
# 2       Acct_MName   Acct_MName      1.0     NaN     NaN
# 3      Acct_UIDNo.  Acct_UIDNo.      1.0     NaN     NaN
# 4       Acct_FName   Acct_FName      1.0     NaN     NaN
# ...            ...          ...      ...     ...     ...
# 13955   Acct_FName   Acct_FName      1.0     NaN     NaN
# 13956    Acct_City    Acct_City      1.0     NaN     NaN
# 13957     Acct_DOB     Acct_DOB      1.0     NaN     NaN
# 13958    Acct_City   Acct_phone      0.0     NaN     NaN
# 13959   Acct_LName   Acct_LName      1.0     NaN     NaN
#
# [13960 rows x 5 columns]
